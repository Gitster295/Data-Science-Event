# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Car_Rental_Bookings.csv',index_col=False)
data
# Out:
#      BookingID CarModel  CustomerAge BookingDate  ReturnDate      City  \
# 0     BOOK1000     Ford           62  2023-07-29  2023-06-19  New York
# 1     BOOK1001   Toyota           44  2023-01-19  2023-04-19   Chicago
# 2     BOOK1002      BMW           37  2023-07-15  2023-05-28  New York
# 3     BOOK1003   Toyota           20  2023-11-22  2023-06-26   Phoenix
# 4     BOOK1004   Toyota           33  2023-04-25  2023-07-09  New York
# ...        ...      ...          ...         ...         ...       ...
# 1020  BOOK1668    Tesla           37  2023-09-15  2023-12-02   Chicago
# 1021  BOOK1830      BMW           27  2023-06-08  2023-10-25   Phoenix
# 1022  BOOK1776      BMW           56  2023-06-18  2023-09-13  New York
# 1023  BOOK1297   Toyota           28  2023-06-19  2023-09-20   Phoenix
# 1024  BOOK1712    Honda           34  2023-07-23  2023-07-27   Houston
#
#       RentalCost PaymentMethod
# 0         412.09   Credit Card
# 1         262.62        Online
# ...

# %%
data.isnull().sum()
# Out:
# BookingID         0
# CarModel          0
# CustomerAge       0
# BookingDate       0
# ReturnDate        0
# City              0
# RentalCost       39
# PaymentMethod     0
# dtype: int64

# %%
std_dev = data['RentalCost'].std()
std_dev
# Out:
# 137.70683716094823

# %%
data.fillna(std_dev,inplace=True)

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# BookingID        0
# CarModel         0
# CustomerAge      0
# BookingDate      0
# ReturnDate       0
# City             0
# RentalCost       0
# PaymentMethod    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(25)

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().any()
# Out:
# np.False_

# %%
data
# Out:
#     BookingID CarModel  CustomerAge BookingDate  ReturnDate         City  \
# 0    BOOK1000     Ford           62  2023-07-29  2023-06-19     New York
# 1    BOOK1001   Toyota           44  2023-01-19  2023-04-19      Chicago
# 2    BOOK1002      BMW           37  2023-07-15  2023-05-28     New York
# 3    BOOK1003   Toyota           20  2023-11-22  2023-06-26      Phoenix
# 4    BOOK1004   Toyota           33  2023-04-25  2023-07-09     New York
# ..        ...      ...          ...         ...         ...          ...
# 995  BOOK1995     Ford           61  2023-06-25  2023-07-30      Chicago
# 996  BOOK1996    Honda           51  2023-12-30  2023-09-11  Los Angeles
# 997  BOOK1997      BMW           53  2023-09-21  2023-05-14      Chicago
# 998  BOOK1998     Ford           47  2023-02-11  2023-10-02      Chicago
# 999  BOOK1999     Ford           52  2023-04-29  2023-04-17  Los Angeles
#
#      RentalCost PaymentMethod
# 0        412.09   Credit Card
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BookingID      1000 non-null   object
#  1   CarModel       1000 non-null   object
#  2   CustomerAge    1000 non-null   int64
#  3   BookingDate    1000 non-null   object
#  4   ReturnDate     1000 non-null   object
#  5   City           1000 non-null   object
#  6   RentalCost     1000 non-null   float64
#  7   PaymentMethod  1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 102.6+ KB

# %% [markdown]
# # Questions & Solutions

# %% [markdown]
# # 1. What is the average value of a key numerical column?

# %%
avg_cost = np.average(data['RentalCost'])
avg_cost
# Out:
# np.float64(261.5728193006332)

# %% [markdown]
# # 2. Find the top 5 most frequent categories in a categorical column.

# %%
CarModel = np.unique(data['CarModel'])
CarModel
# Out:
# array(['BMW', 'Ford', 'Honda', 'Tesla', 'Toyota'], dtype=object)

# %%
City = np.unique(data['City'])
City
# Out:
# array(['Chicago', 'Houston', 'Los Angeles', 'New York', 'Phoenix'],
#       dtype=object)

# %%
PaymentMethod = np.unique(data['PaymentMethod'])
PaymentMethod
# Out:
# array(['Cash', 'Credit Card', 'Debit Card', 'Online'], dtype=object)

# %% [markdown]
# # 3. Identify and handle missing values in the dataset.
#
# I've solved the question above in the block codes 3-12

# %% [markdown]
# # 4. Determine correlation between two numerical columns.

# %% [markdown]
# a.) BookingID is the primary key constraint that has correlation along with all the other attributes as like (Car Model, CustomerAge, BookingDate, ReturnDate, City, RentalCost, PaymrntMethod).
#
# b.) CarModel is correlated to the attributes (BookingDate, ReturnDate, RentalCost, PaymentMethod and City).
#
# c.) BookingDate is correlated to the attributes RentalDate, City and CardModel vice versa for ReturnDate.
#
# d.) RentalCost is correlated to CarModel and the paymentMethod.
#
# e.) The aatrritbutes customerge and city is somewhere correlated to each other in the perspective of customers detail.

# %%
data
# Out:
#     BookingID CarModel  CustomerAge BookingDate  ReturnDate         City  \
# 0    BOOK1000     Ford           62  2023-07-29  2023-06-19     New York
# 1    BOOK1001   Toyota           44  2023-01-19  2023-04-19      Chicago
# 2    BOOK1002      BMW           37  2023-07-15  2023-05-28     New York
# 3    BOOK1003   Toyota           20  2023-11-22  2023-06-26      Phoenix
# 4    BOOK1004   Toyota           33  2023-04-25  2023-07-09     New York
# ..        ...      ...          ...         ...         ...          ...
# 995  BOOK1995     Ford           61  2023-06-25  2023-07-30      Chicago
# 996  BOOK1996    Honda           51  2023-12-30  2023-09-11  Los Angeles
# 997  BOOK1997      BMW           53  2023-09-21  2023-05-14      Chicago
# 998  BOOK1998     Ford           47  2023-02-11  2023-10-02      Chicago
# 999  BOOK1999     Ford           52  2023-04-29  2023-04-17  Los Angeles
#
#      RentalCost PaymentMethod
# 0        412.09   Credit Card
# ...

# %% [markdown]
# # 5. Group the data by a categorical column and calculate aggregate metrics.

# %%
res_car = data.groupby('CarModel').agg({
    'RentalCost': ['sum','mean'],
    'BookingID': 'count'
})
res_payment = data.groupby('PaymentMethod').agg({
    'RentalCost': ['sum','mean',"count"],
    'BookingID': 'count',
    'CarModel': 'count'
})

# %%
res_car
# Out:
#             RentalCost             BookingID
#                    sum        mean     count
# CarModel
# BMW       51315.487860  264.512824       194
# Ford      52167.511023  277.486761       188
# Honda     57369.018372  268.079525       214
# Tesla     45705.957349  256.775041       178
# Toyota    55014.844697  243.428516       226

# %%
res_payment
# Out:
#                  RentalCost                   BookingID CarModel
#                         sum        mean count     count    count
# PaymentMethod
# Cash           70442.920511  258.981325   272       272      272
# Credit Card    60219.968883  268.839147   224       224      224
# Debit Card     63355.418372  260.721886   243       243      243
# Online         67554.511534  258.829546   261       261      261

# %% [markdown]
# # 6. Plot the distribution of a key numerical column using a histogram or KDE plot.

# %%
sns.histplot(data['RentalCost'],kde=True,color='#7AC6D2')
# Out:
# <Axes: xlabel='RentalCost', ylabel='Count'>

# %% [markdown]
# # 7. Create a bar plot to compare categories of a column.

# %%
car_counts = data['CarModel'].value_counts()
plt.figure(figsize=(10, 6))
car_counts.plot(kind='bar', color='#A6D1C3')
plt.title('Number of Rentals per Car Model')
plt.xlabel('Car Model')
plt.ylabel('Number of Rentals')
plt.show()

# %% [markdown]
# # 8. Generate a heatmap to show correlation among numerical columns.

# %%
numerical_data = data.select_dtypes(include=['number'])

corr_matrix = numerical_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")

plt.title('Correlation Heatmap of Numerical Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Create a line plot or time series plot to analyze trends over time.

# %%
data['BookingDate'] =pd.to_datetime(data['BookingDate'])
data['ReturnDate'] = pd.to_datetime(data['ReturnDate'])

# %%
data['BookingDate'] = pd.to_datetime(data['BookingDate'])
data['BookingMonth'] = data['BookingDate'].dt.to_period('M').astype(str)

trend = data.groupby(['BookingMonth', 'CarModel'])['RentalCost'].sum().unstack()

trend.plot(kind='line', figsize=(12, 6), marker='s')
plt.title('Monthly Rental Revenue by Car Model')
plt.xlabel('Month')
plt.ylabel('Total Rental Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Use a box plot to detect outliers in a numerical column.

# %%
sns.boxplot(x=data['CarModel'],y=data['RentalCost'],fill=False,color='Cyan')
# Out:
# <Axes: xlabel='CarModel', ylabel='RentalCost'>
